# %%
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# Setup complete. Using torch 2.2.1+cu121 (Tesla T4)

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="jKvWwcTktuyrPpVQn4bp")
project = rf.workspace("monikaprojects").project("flowers-rose-carnation")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/Flowers(Rose-Carnation)-3 in yolov5pytorch:: 100%|██████████| 4188/4188 [00:01<00:00, 2833.40it/s]

# %%
#data store in content/yolo5/runs/train/exp
# !python train.py --img 640 --batch 20 --epochs 100 --data "/content/datasets/Flowers(Rose-Carnation)-3/data.yaml" --weights yolov5s.pt --cache
# Out:
# 2024-05-14 08:36:01.996344: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-14 08:36:01.996399: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-14 08:36:02.000072: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# source 0 -----> webcam
# source /path of video
# source ---> url of youtube
#data store in content/yolo5/runs/train/exp/weights/best.pt

# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.1 --source /content/RC.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/RC.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-312-g1bcd17ee Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/RC.jpg: 640x640 6 Carnations, 5 Roses, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 540.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.1 --source /content/RC.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/RC.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-312-g1bcd17ee Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/RC.jpg: 640x640 6 Carnations, 5 Roses, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 558.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4
